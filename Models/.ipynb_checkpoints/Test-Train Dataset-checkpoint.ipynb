# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("carprices.csv")
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %% [markdown]
# # Car Mileage VS Sell Price

# %%
plt.scatter([[df.Mileage]],df["Sell Price($)"])
plt.xlabel("Mileage")
plt.ylabel("Prices")
# Out:
# Text(0, 0.5, 'Prices')

# %% [markdown]
# # Age VS Sell Price

# %%
plt.scatter([[df["Age(yrs)"]]],df["Sell Price($)"])
plt.xlabel("Age")
plt.ylabel("Prices")
# Out:
# Text(0, 0.5, 'Prices')

# %%
X = df[["Mileage","Age(yrs)"]]
y = df["Sell Price($)"]

# %%
X.head()
# Out:
#    Mileage  Age(yrs)
# 0    69000         6
# 1    35000         3
# 2    57000         5
# 3    22500         2
# 4    46000         4

# %%
y.head()
# Out:
# 0    18000
# 1    34000
# 2    26100
# 3    40000
# 4    31500
# Name: Sell Price($), dtype: int64

# %%
from sklearn import model_selection

# %%
X_train,X_test,y_train,y_test = model_selection.train_test_split(X,y,test_size=.2)

# %%
(len(X_train)/len(X))*100  # Train Data Percentage 80 %
# Out:
# 80.0

# %%
(len(X_test)/len(X))*100  # Test Data Percentage 20 %
# Out:
# 20.0

# %%
from sklearn import linear_model

# %%
model = linear_model.LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([28030.137675  , 15141.67864685, 18281.01895947, 22624.38881363])

# %%
np.array(y_test)
# Out:
# array([28200, 12800, 19500, 22000])

# %% [markdown]
# # Not Correct Results. Let's See the accuray

# %%
model.score(X_test,y_test)
# Out:
# 0.9393262712769165
