# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
import math
import word2number as w2n

# %% [markdown]
# # PROBLEM
#
# Which of these lines has a best fit?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # SOLUTION
# MEAN SQUARED ERROR OR COST FUNCTION
# ![image.png](attachment:image.png)

# %% [markdown]
# # DELTA = actual - predicted value
# # Predicted value = mx + b

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # GRADIENT DESCENT
#
# It help find the best fit line from the training data set.
# - Less Iteration
# - Efficient
