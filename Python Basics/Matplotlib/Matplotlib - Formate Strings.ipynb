# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5,6,7]
y = [22,34,9,23,32,61,17]

# %%
plt.plot(x,y,"g+")

# %%
plt.plot(x,y,"rD")

# %%
plt.plot(x,y,color="blue",marker="D",linestyle="--",alpha=.4)
