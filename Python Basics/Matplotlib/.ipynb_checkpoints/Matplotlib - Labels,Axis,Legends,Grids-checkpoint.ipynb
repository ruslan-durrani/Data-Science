# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# plt.plot([1],[1],"rD")
days=[1,2,3,4,5,6,7]
max_t=[41,51,62,32,42,62,42]
min_t=[26,11,32,35,52,32,22]
avg_t=[30,51,27,53,45,32,52]

# %%
plt.plot(days,max_t,"rD", linestyle="--")
