# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
companies = ["Google","Meta","Amazon","Ebay","Youtube","Tesla","Space X","Apple","Samsung"]
revenue = [999,435,523,568,789,980,534,735,897]

# %%
plt.xlabel("Companies")
plt.ylabel("Revenue")
plt.bar(companies,revenue,color="b",)
# Out:
# <BarContainer object of 9 artists>

# %%
companies = ["Google","Meta","Amazon","Ebay","Youtube","Tesla","Space X","Apple","Samsung"]
revenue = [999,435,523,568,789,980,534,735,897]
profits = [123,123,123,123,123,123,123,123,123]

xpos = [1,2,3,4,5,6,7,8,9]
plt.xticks(xpos,companies)
plt.bar(xpos,revenue,width=0.4, color='g', label="Revenue")
plt.bar(xpos,profits,width=0.4, color='r',label="Profits")
plt.legend(["COMPANIES","REVENUE"])
plt.xlabel("COMPANIES")
plt.ylabel("REVENUE")
# Out:
# Text(0, 0.5, 'REVENUE')
